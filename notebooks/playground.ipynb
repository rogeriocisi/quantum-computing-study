# %% [markdown]
# # 🌌 Quantum Computing Study - Playground
#
# Use this notebook to run visual experiments, plot probability distributions, and test algorithms implemented in the `src/` directory.

# %%
# 1. Environment Setup
import sys
import os

# Add the project root directory to the Python execution path
sys.path.append(os.path.abspath(os.path.join('..')))

# Enable automatic reloading of external modules
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 2. Usage Example
#
# Let's import a demo circuit from the core codebase.

# %%
from src.algorithms.deutsch_jozsa import build_oracle

# Create a 3-qubit balanced oracle
qc = build_oracle(n_qubits=3, balanced=True)

print(f"Circuit depth: {qc.depth()}")
# Out:
# Circuit depth: 1

# %% [markdown]
# ## 3. Visualization
#
# Draw the quantum circuit in text mode (or switch to `'mpl'` if matplotlib is configured).

# %%
print(qc.draw(output='text'))
# Out:
#
# q_0: ─────
#
# q_1: ─────
#
# q_2: ─────
#      ┌───┐
# q_3: ┤ X ├
#      └───┘
